# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from opencv-python) (1.26.4)

# %%
# !pip install opencv-contrib-python
# Out:
# Requirement already satisfied: opencv-contrib-python in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (4.10.0.84)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from opencv-contrib-python) (1.26.4)

# %%
# !pip install deepface
# Out:
# Requirement already satisfied: deepface in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (0.0.93)
# Requirement already satisfied: requests>=2.27.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.31.0)
# Requirement already satisfied: numpy>=1.14.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.26.4)
# Requirement already satisfied: pandas>=0.23.4 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.5.1)
# Requirement already satisfied: gdown>=3.10.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (5.2.0)
# Requirement already satisfied: tqdm>=4.30.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.66.1)
# Requirement already satisfied: Pillow>=5.2.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (9.3.0)
# Requirement already satisfied: opencv-python>=4.5.5.64 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (4.10.0.84)
# Requirement already satisfied: tensorflow>=1.9.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: keras>=2.2.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (2.10.0)
# Requirement already satisfied: Flask>=1.1.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (3.0.3)
# Requirement already satisfied: flask-cors>=4.0.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (5.0.0)
# Requirement already satisfied: mtcnn>=0.1.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (1.0.0)
# Requirement already satisfied: retina-face>=0.0.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.0.17)
# Requirement already satisfied: fire>=0.4.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (0.7.0)
# Requirement already satisfied: gunicorn>=20.1.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from deepface) (23.0.0)
# Requirement already satisfied: termcolor in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from fire>=0.4.0->deepface) (2.4.0)
# Requirement already satisfied: Werkzeug>=3.0.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.0.1)
# Requirement already satisfied: Jinja2>=3.1.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (3.1.2)
# Requirement already satisfied: itsdangerous>=2.1.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (2.2.0)
# Requirement already satisfied: click>=8.1.3 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (8.1.7)
# Requirement already satisfied: blinker>=1.6.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Flask>=1.1.2->deepface) (1.8.2)
# Requirement already satisfied: beautifulsoup4 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (4.12.2)
# Requirement already satisfied: filelock in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from gdown>=3.10.1->deepface) (3.13.1)
# Requirement already satisfied: packaging in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from gunicorn>=20.1.0->deepface) (21.3)
# Requirement already satisfied: joblib>=1.4.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from mtcnn>=0.1.0->deepface) (1.4.2)
# Requirement already satisfied: lz4>=4.3.3 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from mtcnn>=0.1.0->deepface) (4.3.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from pandas>=0.23.4->deepface) (2022.6)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (2.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests>=2.27.1->deepface) (2023.11.17)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.6.3)
# Requirement already satisfied: flatbuffers>=2.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (24.3.25)
# Requirement already satisfied: gast<=0.4.0,>=0.2.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.12.1)
# Requirement already satisfied: keras-preprocessing>=1.1.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.1.2)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (18.1.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.3.0)
# Requirement already satisfied: protobuf<3.20,>=3.9.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (3.19.6)
# Requirement already satisfied: setuptools in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (57.4.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (4.8.0)
# Requirement already satisfied: wrapt>=1.11.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.16.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (1.62.1)
# Requirement already satisfied: tensorboard<2.11,>=2.10 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.1)
# Requirement already satisfied: tensorflow-estimator<2.11,>=2.10.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorflow>=1.9.0->deepface) (2.10.0)
# Requirement already satisfied: colorama in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tqdm>=4.30.0->deepface) (0.4.6)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from astunparse>=1.6.0->tensorflow>=1.9.0->deepface) (0.43.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from Jinja2>=3.1.2->Flask>=1.1.2->deepface) (2.1.3)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.35.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.6)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (1.8.1)
# Requirement already satisfied: soupsieve>1.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from beautifulsoup4->gdown>=3.10.1->deepface) (2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from packaging->gunicorn>=20.1.0->deepface) (3.0.9)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests[socks]->gdown>=3.10.1->deepface) (1.7.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (5.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (2.0.0)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (0.6.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\aryan bansal\appdata\local\programs\python\python310\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.11,>=2.10->tensorflow>=1.9.0->deepface) (3.2.2)

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.10.0

# %%
import cv2

# %%
img=cv2.imread("C:/Users/Aryan Bansal/Downloads/happyboy.jpeg")

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
# !pip install tf-keras

# %%
import tensorflow as tf
from deepface import DeepFace

# %%
predictions=DeepFace.analyze(img)
# Out:
# Action: race: 100%|██████████████████████████████████████████████████████████████████████| 4/4 [00:15<00:00,  3.88s/it]

# %%
predictions
# Out:
# [{'emotion': {'angry': 1.2172701735480018e-08,
#    'disgust': 1.2703108794411313e-18,
#    'fear': 1.2543603308823315e-10,
#    'happy': 99.99454021453857,
#    'sad': 2.845840008092182e-07,
#    'surprise': 1.546541028574211e-05,
#    'neutral': 0.005443253758130595},
#   'dominant_emotion': 'happy',
#   'region': {'x': 959,
#    'y': 479,
#    'w': 942,
#    'h': 942,
#    'left_eye': (1575, 856),
#    'right_eye': (1260, 870)},
#   'face_confidence': 0.91,
#   'age': 23,
#   'gender': {'Woman': 35.800084471702576, 'Man': 64.19991850852966},
#   'dominant_gender': 'Man',
#   'race': {'asian': 1.9862044602632523,
#    'indian': 2.0221583545207977,
#    'black': 0.5988278426229954,
#    'white': 37.34894096851349,
#    'middle eastern': 9.308125078678131,
#    'latino hispanic': 48.73574078083038},
#   'dominant_race': 'latino hispanic'}]

# %%
predictions[0]['dominant_emotion']
# Out:
# 'happy'

# %%
import cv2

# Make sure to provide the correct path to the XML file
faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')

# %%
gray=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
faces=faceCascade.detectMultiScale(gray,1.1,4)
for(x,y,w,h) in faces:
    cv2.rectangle(img,(x,y),(x+w,y+h),(0,255,0),5)

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
font=cv2.FONT_HERSHEY_SIMPLEX
cv2.putText(img,predictions[0]['dominant_emotion'],(150,500),font,10,(0,0,255),5,cv2.LINE_4);

# %%
plt.imshow(cv2.cvtColor(img,cv2.COLOR_BGR2RGB))

# %%
import cv2
from deepface import DeepFace

faceCascade = cv2.CascadeClassifier(cv2.data.haarcascades + 'haarcascade_frontalface_default.xml')
cap = cv2.VideoCapture(1)

if not cap.isOpened():
    cap = cv2.VideoCapture(0)
if not cap.isOpened():
    raise IOError("Cannot open Webcam!")

while True:
    ret, frame = cap.read()
    
    # Set enforce_detection=False to prevent errors when no face is detected
    try:
        result = DeepFace.analyze(frame, actions=['emotion'], enforce_detection=False)
        dominant_emotion = result[0]['dominant_emotion']
    except ValueError:
        dominant_emotion = "No Face Detected"

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
    faces = faceCascade.detectMultiScale(gray, 1.1, 4)
    for (x, y, w, h) in faces:
        cv2.rectangle(frame, (x, y), (x + w, y + h), (0, 255, 0), 5)

    font = cv2.FONT_HERSHEY_SIMPLEX
    cv2.putText(frame, dominant_emotion, (50, 50), font, 1, (0, 0, 255), 2, cv2.LINE_AA)
    cv2.imshow('Demo Video', frame)

    if cv2.waitKey(2) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
